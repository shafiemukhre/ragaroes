# %%
pip install -U duckduckgo_search
# Out:
# ...
#   Using cached duckduckgo_search-4.4-py3-none-any.whl (20 kB)
# ...
#   Using cached curl_cffi-0.6.0b9-cp38-abi3-macosx_11_0_arm64.whl (2.3 MB)
# ...
#   Using cached lxml-5.1.0-cp39-cp39-macosx_11_0_arm64.whl (4.5 MB)
# ...
#   Using cached docstring_inheritance-2.1.2-py3-none-any.whl (21 kB)
# ...
#   Using cached cffi-1.16.0-cp39-cp39-macosx_11_0_arm64.whl (176 kB)
# ...
#   Using cached pycparser-2.21-py2.py3-none-any.whl (118 kB)
# ...
# WARNING: You are using pip version 22.0.4; however, version 24.0 is available.
# You should consider upgrading via the '/Users/parthjain/Desktop/project/ragaroes/venv/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
from duckduckgo_search import AsyncDDGS
from typing import Dict, Iterator, Optional
# def news(
#     keywords: str,
#     region: str = "wt-wt",
#     safesearch: str = "moderate",
#     timelimit: Optional[str] = None,
#     max_results: Optional[int] = None,
# ) -> Iterator[Dict[str, Optional[str]]]:
#     """DuckDuckGo news search. Query params: https://duckduckgo.com/params

#     Args:
#         keywords: keywords for query.
#         region: wt-wt, us-en, uk-en, ru-ru, etc. Defaults to "wt-wt".
#         safesearch: on, moderate, off. Defaults to "moderate".
#         timelimit: d, w, m. Defaults to None.
#         max_results: max number of results. If None, returns results only from the first response. Defaults to None.

#     Yields:
#         dict with news search results.

#     """

from duckduckgo_search import DDGS
x = []
async def news(search):
  async with AsyncDDGS() as ddgs:
      keywords = search
      ddgs_news_gen = ddgs.news(
        keywords,
        region="wt-wt",
        safesearch="off",
        timelimit="m",
        max_results=1000
      )
      async for r in ddgs_news_gen:
          x.append(r)
  return x

# %%
import asyncio

x = asyncio.run(news("Apple"))

# %%
x
# Out:
# [{'date': '2024-02-04T01:41:00+00:00',
#   'title': 'The Apple Vision Pro Is Spectacular and Sad',
#   'body': 'To stave off this nagging sense of unreality, one can select one of Apple\'s built-in "environments"—virtual scenes with animation and sound—that blend in and out of view as you turn the knob on the visor\'s top. Using my eyes as a mouse, I selected White Sands, a view of a turbulent sky over the gypsum dunes of southern New Mexico.',
#   'url': 'https://www.msn.com/en-us/lifestyle/shopping/the-apple-vision-pro-is-spectacular-and-sad/ar-BB1hJhkO',
#   'image': 'https://cdn.theatlantic.com/thumbor/cGTHPfeIxcyCtfSNGRZFJsj8mfY=/0x102:4792x2598/1200x625/media/img/mt/2024/02/HR_1258467649_1/original.jpg',
#   'source': 'The Atlantic on MSN.com'},
#  {'date': '2024-02-03T23:12:00+00:00',
#   'title': "Forget The New MacBook Pro, Apple's Jony Ive Had Something Much Better",
# ...

# %%
async def news(search):
  async with AsyncDDGS() as ddgs:
      keywords = search
      ddgs_news_gen = ddgs.news(
        keywords,
        region="wt-wt",
        safesearch="off",
        timelimit="m",
        max_results=1000
      )
      async for r in ddgs_news_gen:
          x.append(r)
  return x

# %%
asyncio news("Apple")
# Out:
#   Cell In[6], line 1
#     asyncio news("Apple")
#             ^
# SyntaxError: invalid syntax

# %%
# !pip install yfinance
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.4/72.4 kB 174.8 kB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 357.7 kB/s eta 0:00:0000:0100:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.8/11.8 MB 378.9 kB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.2/112.2 kB 1.1 MB/s eta 0:00:00a 0:00:01
# ...
#   Using cached requests-2.31.0-py3-none-any.whl (62 kB)
# ...
#   Using cached webencodings-0.5.1-py2.py3-none-any.whl (11 kB)
# ...
#   Created wheel for peewee: filename=peewee-3.17.0-cp39-cp39-macosx_11_0_arm64.whl size=245145 sha256=91c37622b680cc997460418216d8196c85a9c11e439c052294f7cfae55faf377
#   Stored in directory: /Users/parthjain/Library/Caches/pip/wheels/77/6b/dc/722aee2a5d46a021ab67564c9d3d5536c3bd9577fcdc3a5aeb
# Successfully built peewee
# ...
#   Attempting uninstall: requests
# ...

# %%
import yfinance as yf
from datetime import datetime
ticker = yf.Ticker("AAPL")

end_date = datetime.now().strftime('%Y-%m-%d')
hist = ticker.history(start='2022-01-01',end=end_date)


hist.head()
# Out:
# /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/yfinance/utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
#                                  Open        High         Low       Close  \
# Date
# 2022-01-03 00:00:00-05:00  175.821115  180.814070  175.702476  179.953888
# 2022-01-04 00:00:00-05:00  180.566891  180.873387  177.096533  177.669983
# 2022-01-05 00:00:00-05:00  177.581006  178.134677  172.667149  172.943985
# 2022-01-06 00:00:00-05:00  170.749050  173.319685  169.701027  170.056961
# 2022-01-07 00:00:00-05:00  170.936919  172.172799  169.097931  170.225052
#
#                               Volume  Dividends  Stock Splits
# Date
# 2022-01-03 00:00:00-05:00  104487900        0.0           0.0
# 2022-01-04 00:00:00-05:00   99310400        0.0           0.0
# ...

# %%
# !pip install llama-index
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.9/15.9 MB 516.0 kB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 388.2/388.2 kB 866.1 kB/s eta 0:00:0000:0100:01
# ...
#   Using cached nltk-3.8.1-py3-none-any.whl (1.5 MB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 955.6/955.6 kB 761.8 kB/s eta 0:00:00a 0:00:01
# ...
#   Using cached typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 351.7 kB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 226.0/226.0 kB 313.0 kB/s eta 0:00:0000:0100:01
# ...
#   Using cached httpx-0.26.0-py3-none-any.whl (75 kB)
# ...
#   Using cached aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# ...
#   Using cached anyio-4.2.0-py3-none-any.whl (85 kB)
# ...
#   Using cached sniffio-1.3.0-py3-none-any.whl (10 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 394.2/394.2 kB 556.1 kB/s eta 0:00:00a 0:00:01
# ...
#   Using cached distro-1.9.0-py3-none-any.whl (20 kB)
# ...

# %%
from llama_index import VectorStoreIndex, SimpleDirectoryReader

documents = SimpleDirectoryReader("data").load_data()
index = VectorStoreIndex.from_documents(documents)
query_engine = index.as_query_engine()
response = query_engine.query("What did the author do growing up?")
print(response)
# Out:
#   Cell In[58], line 1
#     from llama-index import LlamaIndex
#               ^
# SyntaxError: invalid syntax

# %%
from llama_index import (
    SimpleDirectoryReader,
    VectorStoreIndex,
    StorageContext,
    load_index_from_storage,
)

from llama_index.tools import QueryEngineTool, ToolMetadata

# %%
# !pip install pypdf
# !pip install openai

# %%
import os 
os.environ['OPENAI_API_KEY'] = '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'

# %%
try:
    storage_context = StorageContext.from_defaults(
        persist_dir="./storage/lyft"
    )
    lyft_index = load_index_from_storage(storage_context)

    storage_context = StorageContext.from_defaults(
        persist_dir="./storage/uber"
    )
    uber_index = load_index_from_storage(storage_context)

    index_loaded = True
except:
    index_loaded = False

# %%
if not index_loaded:
    # load data
    lyft_docs = SimpleDirectoryReader(
        input_files=["/Users/parthjain/Desktop/project/ragaroes/pdf_files/Facebook-Reports-First-Quarter-2021-Results-2021.pdf"]
    ).load_data()
    uber_docs = SimpleDirectoryReader(
        input_files=["/Users/parthjain/Desktop/project/ragaroes/pdf_files/Meta-Third-Quarter-2022.pdf"]
    ).load_data()

    # build index
    lyft_index = VectorStoreIndex.from_documents(lyft_docs)
    uber_index = VectorStoreIndex.from_documents(uber_docs)

    # persist index
    lyft_index.storage_context.persist(persist_dir="./storage/lyft")
    uber_index.storage_context.persist(persist_dir="./storage/uber")

# %%
lyft_engine = lyft_index.as_query_engine(similarity_top_k=3)
uber_engine = uber_index.as_query_engine(similarity_top_k=3)

# %%
query_engine_tools = [
    QueryEngineTool(
        query_engine=lyft_engine,
        metadata=ToolMetadata(
            name="meta_2021_Q1",
            description=(
                "Provides information about Meta financials for year 2021 and quater 1 "
                "Use a detailed plain text question as input to the tool."
            ),
        ),
    ),
    QueryEngineTool(
        query_engine=uber_engine,
        metadata=ToolMetadata(
            name="Meta_2022_Q3",
            description=(
                "Provides information about Meta financials for year 2022 quater 3. "
                "Use a detailed plain text question as input to the tool."
            ),
        ),
    ),
]

# %%
from llama_index.agent import ReActAgent
from llama_index.llms import OpenAI

# %%
llm = OpenAI(model="gpt-3.5-turbo-0613")

agent = ReActAgent.from_tools(
    query_engine_tools,
    llm=llm,
    verbose=True,
    # context=context
)

# %%
response = agent.chat("What was Meta's revenue growth in 2021 Quater 1?")
print(str(response))
# Out:
# Thought: I can use the tool "meta_2021_Q1" to get information about Meta's financials for 2021 Quater 1.
# Action: meta_2021_Q1
# Action Input: {'input': "What was Meta's revenue growth in 2021 Quater 1?"}
# Observation: Meta's revenue growth in the first quarter of 2021 was 48%.
# Thought: I have the information needed to answer the question.
# Answer: Meta's revenue growth in 2021 Quater 1 was 48%.
# Meta's revenue growth in 2021 Quater 1 was 48%.

# %%
response = agent.chat(
    "Compare and contrast the revenue growth of Meta 2021 Q1 and Meta 2022 Q3, then"
    " give an analysis"
)
print(str(response))
# Out:
# Thought: I need to use a tool to help me compare the revenue growth of Meta in 2021 Q1 and 2022 Q3.
# Action: meta_2021_Q1
# Action Input: {'input': "What was Meta's revenue growth in 2021 Quater 1?"}
# Observation: Meta's revenue growth in the first quarter of 2021 was 48%.
# Thought: I need to use another tool to get the revenue growth of Meta in 2022 Q3.
# Action: Meta_2022_Q3
# Action Input: {'input': "What was Meta's revenue growth in 2022 Quater 3?"}
# Observation: Meta's revenue growth in the third quarter of 2022 was -4%.
# Thought: I have the information needed to compare and contrast the revenue growth of Meta in 2021 Q1 and 2022 Q3.
# Answer: The revenue growth of Meta in 2021 Q1 was 48%, while in 2022 Q3 it was -4%. This indicates a significant decrease in revenue growth from 2021 Q1 to 2022 Q3.
# The revenue growth of Meta in 2021 Q1 was 48%, while in 2022 Q3 it was -4%. This indicates a significant decrease in revenue growth from 2021 Q1 to 2022 Q3.

# %%
# Try another query with async execution

import nest_asyncio

nest_asyncio.apply()

response = await agent.achat(
    "Compare and contrast the risks of Meta 2021 in 2021, then give an"
    " analysis"
)
print(str(response))
# Out:
# Thought: I need to use a tool to help me answer the question.
# Action: meta_2021_Q1
# Action Input: {'input': 'What were the risks faced by Uber and Lyft in 2021?'}
# Observation: I'm sorry, but the given context information does not provide any information about the risks faced by Uber and Lyft in 2021.
# Thought: I cannot answer the question with the provided tools.
# Answer: Sorry, I cannot answer your query.
# Sorry, I cannot answer your query.

# %%
{
  "clientId": "JkdUQRXmhMXeTirGLGmBemdd",
  "secret": "Z,0Eq76c+zEz8Ee3tarc5N4zXpplwj9GGMQW11yeZ9v.WMu5NYZc9YqKbUz-bbzAsA_qwq6HtYB3M.Ls1k2I7eqMSBmEOQycxTRFd8rZD0ZflPi23N8aHj6EeZ+MHZTk",
  "token": "AstraCS:JkdUQRXmhMXeTirGLGmBemdd:796782063ee1a223e6d37d1d70aa00b3264090d0b6233c63b9cfd41600a6fb4e"
}
